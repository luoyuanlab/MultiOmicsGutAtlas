# %% [markdown]
# # UC CosMx: Spatial Plots, Protein-based Annotation, and Co-occurrence (Fig 2)
#
# 1. Spatial plots of imputed 1K annotations
# 2. Protein-based annotation (CD68/PanCK Otsu threshold)
# 3. Squidpy co-occurrence analysis

# %%
# ── Paths ──
DATA_DIR   = "/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans"
K1_DIR     = DATA_DIR + "/1k/Processed_merged"
WTX_DIR    = DATA_DIR + "/whole_trans/Processed_merged"
OUTPUT_DIR = K1_DIR + "/spatial_plots"

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import squidpy as sq
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
scrna = sc.read_h5ad('/share/fsmresfiles/UC/scRNA-seq/merged_9p_wip/pdated_annoed_all_cell_types.h5ad')

# %%
adata_wtx_1 = sc.read_h5ad('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/whole_trans/Processed_UC_P1_UC_P2/v7/h5ad_obj/qc_wtx_v7_UC_P1_UC_P2_anno.h5ad')

# %%
adata_wtx_2=sc.read_h5ad('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/whole_trans/Processed_UC_P3_UC_P4/v7/h5ad_obj/qc_wtx_v7_UC_P3_UC_P4_anno.h5ad')

# %%
[i for i in adata_wtx_2.var_names.tolist() if

# %%
adata_wtx=sc.read_h5ad('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/whole_trans/Processed_merged/v7/h5ad_obj/qc_wtx_v7_merged_anno.h5ad')

# %%
adata_wtx

# %%
adata_1k_1=sc.read_h5ad('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/1k/Processed_UC_P1_UC_P2/h5ad_img/imp_ywl_anno.h5ad')
#adata_1k_2=sc.read_h5ad('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/1k/Processed_UC_P3_UC_P4/h5ad_img/imp_ywl_anno.h5ad')

# %%
adata_1k_1

# %%
adata_1k=sc.read_h5ad('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/1k/Processed_merged/h5ad_obj/imp_ywl_anno.h5ad')

# %%
ywl_1k_b = pd.read_csv('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/1k/Processed_merged/anno/ywl_imp_b_log_aucell.csv')
ywl_1k_f = pd.read_csv('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/1k/Processed_merged/anno/ywl_imp_f_log_aucell.csv')

# %%
tangram = pd.read_csv('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/1k/Processed_merged/anno/v7_trained_tangram_imp_log1p_counts_aucell.csv')

# %%
stplus = pd.read_csv('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/1k/Processed_merged/anno/v7_trained_stplus_imp_log1p_counts_aucell.csv')

# %%
adata_6k_custom = sc.read_h5ad('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/6k/Processed_merged_upd/h5ad_obj/qc_6k_merged_log1p_anno_6375genes.h5ad')

# %%
adata_6k= sc.read_h5ad('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/6k/Processed_merged_upd/h5ad_obj/qc_6k_merged_log1p_anno_6175genes.h5ad')

# %%
adata_6k_custom

# %%
adata_6k

# %%
adata_6k_1_custom=sc.read_h5ad('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/6k/Processed_UC_P1_UC_P2_upd/h5ad_obj/qc_6k_UC_batch1_log1p_anno_6375genes.h5ad')
adata_6k_1=sc.read_h5ad('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/6k/Processed_UC_P1_UC_P2_upd/h5ad_obj/qc_6k_UC_batch1_log1p_anno_6175genes.h5ad')

adata_6k_2_custom=sc.read_h5ad('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/6k/Processed_UC_P3_UC_P4_upd/h5ad_obj/qc_6k_UC_batch2_log1p_anno_6375genes.h5ad')
adata_6k_2=sc.read_h5ad('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/6k/Processed_UC_P3_UC_P4_upd/h5ad_obj/qc_6k_UC_batch2_log1p_anno_6175genes.h5ad')

# %%
mapper= pd.read_csv('/share/fsmresfiles/UC/scRNA-seq/merged_9p_wip/cell_type_name_mapper.csv')

# %%
ywl_1k_f=ywl_1k_f.merge(mapper, left_on = 'label',right_on='cell_type_short',how='left')

# %%
ywl_1k_b=ywl_1k_b.merge(mapper, left_on = 'label',right_on='cell_type_short',how='left')

# %%
tangram=tangram.merge(mapper, left_on = 'label',right_on='cell_type_short',how='left')

# %%
stplus=stplus.merge(mapper, left_on = 'label',right_on='cell_type_short',how='left')
stplus

# %%
adata_1k.obs['v7_ywl_f_imp_cell_type_short'] = ywl_1k_f['cell_type_short'].tolist()
adata_1k.obs['v7_ywl_f_imp_cell_type_full'] = ywl_1k_f['cell_type'].tolist()
adata_1k.obs['v7_ywl_f_imp_cell_category_from_type'] = ywl_1k_f['cell_category'].tolist()
adata_1k.obs['v7_ywl_f_imp_cell_type_general'] = ywl_1k_f['cell_type_general'].tolist()

# %%
adata_1k.obs['v7_ywl_b_imp_cell_type_short'] = ywl_1k_b['cell_type_short'].tolist()
adata_1k.obs['v7_ywl_b_imp_cell_type_full'] = ywl_1k_b['cell_type'].tolist()
adata_1k.obs['v7_ywl_b_imp_cell_category_from_type'] = ywl_1k_b['cell_category'].tolist()
adata_1k.obs['v7_ywl_b_imp_cell_type_general'] = ywl_1k_b['cell_type_general'].tolist()

# %%
adata_1k.obs['v7_tan_imp_cell_type_short'] = tangram['cell_type_short'].tolist()
adata_1k.obs['v7_tan_imp_cell_type_full'] = tangram['cell_type'].tolist()
adata_1k.obs['v7_tan_imp_cell_category_from_type'] = tangram['cell_category'].tolist()
adata_1k.obs['v7_tan_imp_cell_type_general'] = tangram['cell_type_general'].tolist()

# %%
adata_1k.obs['v7_stp_imp_cell_type_short'] = stplus['cell_type_short'].tolist()
adata_1k.obs['v7_stp_imp_cell_type_full'] = stplus['cell_type'].tolist()
adata_1k.obs['v7_stp_imp_cell_category_from_type'] = stplus['cell_category'].tolist()
adata_1k.obs['v7_stp_imp_cell_type_general'] = stplus['cell_type_general'].tolist()

# %%
adata_1k_1_sub = adata_1k[adata_1k.obs['patient'].isin(['UC_P1','UC_P2'])]
adata_1k_1_sub_anno_b = adata_1k_1_sub.obs[['v7_ywl_b_imp_cell_type_short','v7_ywl_b_imp_cell_type_full','v7_ywl_b_imp_cell_category_from_type','v7_ywl_b_imp_cell_type_general']]
adata_1k_1_sub_anno_f = adata_1k_1_sub.obs[['v7_ywl_f_imp_cell_type_short','v7_ywl_f_imp_cell_type_full','v7_ywl_f_imp_cell_category_from_type','v7_ywl_f_imp_cell_type_general']]

# %%
adata_1k_1_sub = adata_1k[adata_1k.obs['patient'].isin(['UC_P1','UC_P2'])]
adata_1k_1_sub_anno_tan = adata_1k_1_sub.obs[['v7_tan_imp_cell_type_short','v7_tan_imp_cell_type_full','v7_tan_imp_cell_category_from_type','v7_tan_imp_cell_type_general']]

# %%
adata_1k_1_sub = adata_1k[adata_1k.obs['patient'].isin(['UC_P1','UC_P2'])]
adata_1k_1_sub_anno_stp= adata_1k_1_sub.obs[['v7_stp_imp_cell_type_short','v7_stp_imp_cell_type_full','v7_stp_imp_cell_category_from_type','v7_stp_imp_cell_type_general']]

# %%
adata_1k_2_sub = adata_1k[adata_1k.obs['patient'].isin(['UC_P3','UC_P4'])]
adata_1k_2_sub_anno_b = adata_1k_2_sub.obs[['v7_ywl_b_imp_cell_type_short','v7_ywl_b_imp_cell_type_full','v7_ywl_b_imp_cell_category_from_type','v7_ywl_b_imp_cell_type_general']]
adata_1k_2_sub_anno_f = adata_1k_2_sub.obs[['v7_ywl_f_imp_cell_type_short','v7_ywl_f_imp_cell_type_full','v7_ywl_f_imp_cell_category_from_type','v7_ywl_f_imp_cell_type_general']]

# %%
adata_1k_2_sub = adata_1k[adata_1k.obs['patient'].isin(['UC_P3','UC_P4'])]
adata_1k_2_sub_anno_tan = adata_1k_2_sub.obs[['v7_tan_imp_cell_type_short','v7_tan_imp_cell_type_full','v7_tan_imp_cell_category_from_type','v7_tan_imp_cell_type_general']]

# %%
adata_1k_2_sub = adata_1k[adata_1k.obs['patient'].isin(['UC_P3','UC_P4'])]
adata_1k_2_sub_anno_stp = adata_1k_2_sub.obs[['v7_stp_imp_cell_type_short','v7_stp_imp_cell_type_full','v7_stp_imp_cell_category_from_type','v7_stp_imp_cell_type_general']]

# %%
adata_1k_1.obs = adata_1k_1.obs.merge(adata_1k_1_sub_anno_b, how = 'left', left_index=True,right_index=True)
adata_1k_1.obs = adata_1k_1.obs.merge(adata_1k_1_sub_anno_f, how = 'left', left_index=True,right_index=True)

# %%
adata_1k_2.obs = adata_1k_2.obs.merge(adata_1k_2_sub_anno_b, how = 'left', left_index=True,right_index=True)
adata_1k_2.obs = adata_1k_2.obs.merge(adata_1k_2_sub_anno_f, how = 'left', left_index=True,right_index=True)

# %%
adata_1k_1.obs = adata_1k_1.obs.merge(adata_1k_1_sub_anno_tan, how = 'left', left_index=True,right_index=True)
adata_1k_2.obs = adata_1k_2.obs.merge(adata_1k_2_sub_anno_tan, how = 'left', left_index=True,right_index=True)

# %%
adata_1k_1.obs = adata_1k_1.obs.merge(adata_1k_1_sub_anno_stp, how = 'left', left_index=True,right_index=True)
adata_1k_2.obs = adata_1k_2.obs.merge(adata_1k_2_sub_anno_stp, how = 'left', left_index=True,right_index=True)

# %%
adata_1k_1

# %%
adata_1k_2

# %%
anno_1k = pd.read_csv('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/1k/Processed_merged/anno/1kgenes_only_aucell.csv')
anno_1k=anno_1k[['cells','label']]
anno_1k=anno_1k.merge(mapper,left_on = 'label',right_on = 'cell_type_short',how='left')
anno_1k

# %%
adata_1k.obs['only_1k_cell_type']=anno_1k['cell_type'].tolist()
adata_1k.obs['only_1k_cell_cat_from_type']=anno_1k['cell_category'].tolist()
adata_1k.obs['only_1k_cell_type_short']=anno_1k['cell_type_short'].tolist()
adata_1k.obs['only_1k_cell_type_general']=anno_1k['cell_type_general'].tolist()
adata_1k

# %%
adata_1k.obs[['only_1k_cell_cat_from_type', 'only_1k_cell_type_short']].value_counts()

# %%
adata_1k_2_sub = adata_1k[adata_1k.obs['patient'].isin(['UC_P3','UC_P4'])]
adata_1k_1_sub = adata_1k[adata_1k.obs['patient'].isin(['UC_P1','UC_P2'])]

# %%
adata_1k_1.obs['only_1k_cell_type'] = adata_1k_1_sub.obs['only_1k_cell_type'].tolist()
adata_1k_1.obs['only_1k_cell_cat_from_type'] = adata_1k_1_sub.obs['only_1k_cell_cat_from_type'].tolist()
adata_1k_1.obs['only_1k_cell_type_short'] = adata_1k_1_sub.obs['only_1k_cell_type_short'].tolist()
adata_1k_1.obs['only_1k_cell_type_general'] = adata_1k_1_sub.obs['only_1k_cell_type_general'].tolist()

# %%
adata_1k_2.obs['only_1k_cell_type'] = adata_1k_2_sub.obs['only_1k_cell_type'].tolist()
adata_1k_2.obs['only_1k_cell_cat_from_type'] = adata_1k_2_sub.obs['only_1k_cell_cat_from_type'].tolist()
adata_1k_2.obs['only_1k_cell_type_short'] = adata_1k_2_sub.obs['only_1k_cell_type_short'].tolist()
adata_1k_2.obs['only_1k_cell_type_general'] = adata_1k_2_sub.obs['only_1k_cell_type_general'].tolist()

# %%
adata_1k_1.write_h5ad('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/1k/Processed_UC_P1_UC_P2/h5ad_img/imp_ywl_anno.h5ad')
adata_1k_2.write_h5ad('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/1k/Processed_UC_P3_UC_P4/h5ad_img/imp_ywl_anno.h5ad')

# %%
adata_1k.write_h5ad('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/1k/Processed_merged/h5ad_obj/imp_ywl_anno.h5ad')

# %%
test_wtx_1k = adata_wtx_1[adata_wtx_1.obs['train_test_split_pseudo_6k']=='Test']

# %%
test_wtx_1k = test_wtx_1k[:, test_wtx_1k.var_names.isin(adata_1k_1.var_names.tolist())].copy()
test_wtx_1k

# %%
test_wtx_1k_df = pd.DataFrame(test_wtx_1k.X)
test_wtx_1k_df.columns = test_wtx_1k.var_names.tolist()
test_wtx_1k_df.index = test_wtx_1k.obs['fov_cell_id'].tolist()
test_wtx_1k_df

# %%
test_wtx_1k_df.to_csv('/share/fsmresfiles/UC/AtoMx/UC_1k_6k_wholetrans/whole_trans/Processed_UC_P1_UC_P2/v7/count_csv/psuedo_1k.csv')

# %%
slide=[]
for i,j in zip(adata_6k_1.obs['orig.ident'].tolist(),adata_6k_1.obs['fov'].tolist()):
    j= int(j)
    if j <=7:
        slide.append(i+'_'+'slide1')
    elif j > 7 and j <= 32:
        slide.append(i+'_'+'slide2')
    elif j > 32 and j <= 45:
        slide.append(i+'_'+'slide3')
    else:
        slide.append(i+'_'+'slide4')
adata_6k_1.obs['slide']=slide        

slide=[]
for i,j in zip(adata_6k_2.obs['orig.ident'].tolist(),adata_6k_2.obs['fov'].tolist()):
    j= int(j)
    if j <=14:
        slide.append(i+'_'+'slide1')
    elif j > 14 and j <= 18:
        slide.append(i+'_'+'slide2')
    elif j > 18 and j <= 39:
        slide.append(i+'_'+'slide3')
    else:
        slide.append(i+'_'+'slide4')
adata_6k_2.obs['slide']=slide

# %%
slide=[]
for i,j in zip(adata_6k_1_custom.obs['orig.ident'].tolist(),adata_6k_1_custom.obs['fov'].tolist()):
    j= int(j)
    if j <=8:
        slide.append(i+'_'+'slide1')
    elif j > 8 and j <= 34:
        slide.append(i+'_'+'slide2')
    elif j > 34 and j <= 47:
        slide.append(i+'_'+'slide3')
    else:
        slide.append(i+'_'+'slide4')
adata_6k_1_custom.obs['slide']=slide        

slide=[]
for i,j in zip(adata_6k_2_custom.obs['orig.ident'].tolist(),adata_6k_2_custom.obs['fov'].tolist()):
    j= int(j)
    if j <=16:
        slide.append(i+'_'+'slide1')
    elif j > 16 and j <= 24:
        slide.append(i+'_'+'slide2')
    elif j > 24 and j <= 47:
        slide.append(i+'_'+'slide3')
    else:
        slide.append(i+'_'+'slide4')
adata_6k_2_custom.obs['slide']=slide

# %% [markdown]
# # other good looking  tissue

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Subset data for specific slide
adata1_slide3_wtx = adata_wtx_1[adata_wtx_1.obs['slide'] == 'UC_batch1_slide4']
coordinates = adata1_slide3_wtx.obsm['spatial_fov']

category_column = 'aucell_cell_category_from_type'
categories = adata1_slide3_wtx.obs[category_column].astype('category')

# Create a color palette
palette = sns.color_palette('tab20', len(categories.cat.categories))
colors = categories.cat.codes.map(dict(enumerate(palette)))

# Plotting
plt.figure(figsize=(8, 10))
scatter = plt.scatter(coordinates[:, 0], coordinates[:, 1], c=colors, s=2)  # Adjust s for marker size
plt.title("")

# Remove axis labels and tick labels
plt.xlabel("")
plt.ylabel("")
plt.xticks([])  # Remove x-axis tick labels
plt.yticks([])  # Remove y-axis tick labels

# Remove gridlines
plt.grid(False)

# Create a custom legend inside the plot at the top left
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=palette[i], markersize=10) 
           for i in range(len(categories.cat.categories))]
plt.legend(
    handles, 
    categories.cat.categories, 
    title="WTX", 
    loc='upper left', 
    frameon=False,
    fontsize=12,           # Legend label font size
    title_fontsize=14      # Legend title font size
)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(False) 

# Add correlation annotation in bottom right
corr_text = (
    "Spearman's Correlation\n"
    "Epithelial cell & PanCK: 0.553 (p=0.0)\n"
    "Myeloid cell & CD68: 0.188 (p=5.0e-155)"
)

plt.text(
    0.98, 0.02,  # x, y in axes fraction
    corr_text,
    transform=plt.gca().transAxes,
    ha='right', va='bottom',
    fontsize=12,
    bbox=dict(facecolor='white', edgecolor='none', alpha=0.8, boxstyle='round,pad=0.3')
)

# Save to PDF
plt.savefig("WTX_slide4_annotation.jpg", bbox_inches='tight', dpi=300)

plt.show()

# %%
[i for i in adata1_slide3_1k.obs['only_1k_cell_type_general'].unique().tolist() if i not in  adata1_slide3_wtx.obs['aucell_cell_type_general'].unique().tolist()]

# %%
[i for i in adata1_slide3_wtx.obs['aucell_cell_type_general'].unique().tolist() if i not in  adata1_slide3_1k .obs['only_1k_cell_type_general'].unique().tolist()]

# %%
len(adata1_slide3_wtx.obs['aucell_cell_type_general'].unique().tolist() )

# %%
custom_palette_36 = [
    "#1f77b4",  # 'B' - Dark Blue
    "#aec7e8",  # 'ADAMDEC1+ Fib' - Light Blue
    "#8fd1db",  # 'Activated Fib' - Light Blue
    "#8ac0ed",  # 'Crypt Top Fib' - Light Blue
    '#ace8e3', # Cycl fib
    "#a5daf2",  # 'Myofibroblast' - Light Blue
    "#9ad3d6",  # 'OGN+RSPO3+ Fib' - Light Blue
    "#80b7b5",  # 'Pericyte' - Light Blue
    '#c6d6f5', # SELENOP+ fib,
    "#ff7f0e",  # 'Endothelial' - Dark Orange
    "#ffbb78",  # 'Absoprtive Epi' - Light Orange
    '#f5d2b5', # Enteroendocrine
    "#f8c0a9",  # 'Inflamed Epi' - Light Orange
    "#f1a3a3",  # 'M cell' - Light Orange
    "#e39b5f",  # 'Secretive Epi' - Light Orange
    "#e07b5b",  # 'TA' - Light Orange
    "#df9f6e",  # 'Tuft' - Light Orange
    "#2ca02c",  # 'Granulocyte' - Dark Green
    "#98df8a",  # 'Cycl Myeloid' - Light Green 1
    "#8fa72b",  # 'DC' - Light Green 2
    "#9abf62",  # 'Mo-mac' - Light Green 3
    "#a1d99b",  # 'Neutrophil' - Light Green 4
    "#6b9f67",  # 'SELENOP+ Mac' - Light Green 5
    "#d65a69",  # 'NK' - Red
    "#ff9b99",  # 'Neuron' - Salmon
    "#9467bd",  # 'Plasma' - Dark Purple
    "#ebc2ed",  # 'CD4 Trm' - Lighter Purple 1
    "#c0a4de",  # 'CD8 Trm' - Lighter Purple 2
    "#e0c3d9",  #  'Cycl T'
    "#e377c2",  # 'DN T' - Lighter Purple 3
    "#9b6fa3",  # 'Effector T' - Lighter Purple 4
    "#b175b6",  # 'Gd T' - Lighter Purple 5
    "#d2a2b8",  # 'MAIT' - Lighter Purple 6
    "#e4b5c9",  # 'Resting T' - Lighter Purple 7
    "#e1ace8",  # 'Tfh' - Lighter Purple 8
    "#b1b7d2",  # 'Treg' - Lighter Purple 9
]
# Assuming your data is in adata1_slide3_1k and you have the necessary columns
category_column = 'aucell_cell_type_general'
category_from_type_column = 'aucell_cell_category_from_type'

# Sort the data by category and cell type
sorted_categories = adata1_slide3_wtx.obs[[category_column, category_from_type_column]].drop_duplicates()
sorted_categories = sorted_categories.sort_values(by=[category_from_type_column, category_column])

# Create a mapping of the sorted categories to the custom color palette
category_to_color = {cat: custom_palette_36[i] for i, cat in enumerate(sorted_categories[category_column].unique())}

# Map the categories to the colors
categories = adata1_slide3_wtx.obs[category_column].astype('category')
category_colors = categories.map(category_to_color)

# Plotting
plt.figure(figsize=(8.5, 10))
scatter = plt.scatter(adata1_slide3_wtx.obsm['spatial_fov'][:, 0], 
                      adata1_slide3_wtx.obsm['spatial_fov'][:, 1], 
                      c=category_colors, s=2)  # Adjust `s` for marker size
plt.title("WTX UC_P1 Right Tissue Annotation")

# Remove axis labels and tick labels
plt.xlabel("")
plt.ylabel("")
plt.xticks([])  # Remove x-axis tick labels
plt.yticks([])  # Remove y-axis tick labels

# Remove gridlines
plt.grid(False)

# Create a custom legend outside the plot on the right
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10) 
           for color in custom_palette_36]
plt.legend(handles, sorted_categories[category_column].unique(), title="Cell Type", 
           loc='upper left', bbox_to_anchor=(1.05, 1), frameon=False)

plt.tight_layout()  # Ensure there’s no clipping of the legend
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Subset data for specific slide
adata1_slide3_6k = adata_6k_1[adata_6k_1.obs['slide'] == 'UC_batch1_slide4']
coordinates = adata1_slide3_6k.obsm['spatial_fov']

category_column = 'aucell_cell_category_from_type'
categories = adata1_slide3_6k.obs[category_column].astype('category')

# Create a color palette
palette = sns.color_palette('tab20', len(categories.cat.categories))
colors = categories.cat.codes.map(dict(enumerate(palette)))

# Plotting
plt.figure(figsize=(8, 10))
scatter = plt.scatter(coordinates[:, 0], coordinates[:, 1], c=colors, s=2)  # Adjust `s` for marker size
plt.title("6K UC_P1 Right Tissue Annotation")

# Remove axis labels and tick labels
plt.xlabel("")
plt.ylabel("")
plt.xticks([])  # Remove x-axis tick labels
plt.yticks([])  # Remove y-axis tick labels

# Remove gridlines
plt.grid(False)

# Create a custom legend inside the plot at the top right
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=palette[i], markersize=10) 
           for i in range(len(categories.cat.categories))]
plt.legend(handles, categories.cat.categories, title="Major Cell Type", loc='upper left', frameon=False)

plt.show()

# %%
coordinates = adata1_slide3_6k.obsm['spatial_fov']

continuous_column = 'Max.PanCK'
continuous_values = adata1_slide3_6k.obs[continuous_column]

# Choose a colormap (e.g., 'viridis', 'plasma', 'coolwarm')
colormap = plt.cm.viridis

# Normalize the continuous values to range between 0 and 1 for the colormap
norm = plt.Normalize(vmin=continuous_values.min(), vmax=continuous_values.max())
colors = colormap(norm(continuous_values))

# Plotting
plt.figure(figsize=(9, 10))
scatter = plt.scatter(coordinates[:, 0], coordinates[:, 1], c=colors, s=2, cmap=colormap)  # Adjust `s` for marker size
# Remove axis labels and tick labels
plt.title("6K UC_P2 Left Tissue PanCK")
plt.xlabel("")
plt.ylabel("")
plt.xticks([])  # Remove x-axis tick labels
plt.yticks([])  # Remove y-axis tick labels

# Remove gridlines
plt.grid(False)

# Add a colorbar to represent the continuous values
cbar = plt.colorbar(scatter, ax=plt.gca(), aspect=30, pad=0.02)
cbar.set_label(continuous_column, rotation=270, labelpad=15)


plt.show()

# %%
coordinates = adata1_slide3_6k.obsm['spatial_fov']

continuous_column = 'Max.CD68'
continuous_values = adata1_slide3_6k.obs[continuous_column]

# Choose a colormap (e.g., 'viridis', 'plasma', 'coolwarm')
colormap = plt.cm.viridis

# Normalize the continuous values to range between 0 and 1 for the colormap
norm = plt.Normalize(vmin=continuous_values.min(), vmax=continuous_values.max())
colors = colormap(norm(continuous_values))

# Plotting
plt.figure(figsize=(9, 10))
scatter = plt.scatter(coordinates[:, 0], coordinates[:, 1], c=colors, s=2, cmap=colormap)  # Adjust `s` for marker size
# Remove axis labels and tick labels
plt.title("6K UC_P2 Left Tissue CD68")
plt.xlabel("")
plt.ylabel("")
plt.xticks([])  # Remove x-axis tick labels
plt.yticks([])  # Remove y-axis tick labels

# Remove gridlines
plt.grid(False)

# Add a colorbar to represent the continuous values
cbar = plt.colorbar(scatter, ax=plt.gca(), aspect=30, pad=0.02)
cbar.set_label(continuous_column, rotation=270, labelpad=15)


plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Subset data for specific slide
adata1_slide3_6k_custom = adata_6k_1_custom[adata_6k_1_custom.obs['slide'] == 'UC_batch1_slide4']
coordinates = adata1_slide3_6k_custom.obsm['spatial_fov']

category_column = 'aucell_cell_category_from_type'
categories = adata1_slide3_6k_custom.obs[category_column].astype('category')

# Create a color palette
palette = sns.color_palette('tab20', len(categories.cat.categories))
colors = categories.cat.codes.map(dict(enumerate(palette)))

# Plotting
plt.figure(figsize=(8, 10))
scatter = plt.scatter(coordinates[:, 0], coordinates[:, 1], c=colors, s=2)  # Adjust `s` for marker size
plt.title("6K+200Custom UC_P1 Right Tissue Annotation")

# Remove axis labels and tick labels
plt.xlabel("")
plt.ylabel("")
plt.xticks([])  # Remove x-axis tick labels
plt.yticks([])  # Remove y-axis tick labels

# Remove gridlines
plt.grid(False)

# Create a custom legend inside the plot at the top right
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=palette[i], markersize=10) 
           for i in range(len(categories.cat.categories))]
plt.legend(handles, categories.cat.categories, title="Major Cell Type", loc='upper left', frameon=False)

plt.show()

# %%
coordinates = adata1_slide3_6k_custom.obsm['spatial_fov']

continuous_column = 'Max.CD68'
continuous_values = adata1_slide3_6k_custom.obs[continuous_column]

# Choose a colormap (e.g., 'viridis', 'plasma', 'coolwarm')
colormap = plt.cm.viridis

# Normalize the continuous values to range between 0 and 1 for the colormap
norm = plt.Normalize(vmin=continuous_values.min(), vmax=continuous_values.max())
colors = colormap(norm(continuous_values))

# Plotting
plt.figure(figsize=(9, 10))
scatter = plt.scatter(coordinates[:, 0], coordinates[:, 1], c=colors, s=2, cmap=colormap)  # Adjust `s` for marker size
# Remove axis labels and tick labels
plt.title("6K+200Custom UC_P2 Left Tissue CD68")
plt.xlabel("")
plt.ylabel("")
plt.xticks([])  # Remove x-axis tick labels
plt.yticks([])  # Remove y-axis tick labels

# Remove gridlines
plt.grid(False)

# Add a colorbar to represent the continuous values
cbar = plt.colorbar(scatter, ax=plt.gca(), aspect=30, pad=0.02)
cbar.set_label(continuous_column, rotation=270, labelpad=15)


plt.show()

# %%
coordinates = adata1_slide3_6k_custom.obsm['spatial_fov']

continuous_column = 'Max.PanCK'
continuous_values = adata1_slide3_6k_custom.obs[continuous_column]

# Choose a colormap (e.g., 'viridis', 'plasma', 'coolwarm')
colormap = plt.cm.viridis

# Normalize the continuous values to range between 0 and 1 for the colormap
norm = plt.Normalize(vmin=continuous_values.min(), vmax=continuous_values.max())
colors = colormap(norm(continuous_values))

# Plotting
plt.figure(figsize=(9, 10))
scatter = plt.scatter(coordinates[:, 0], coordinates[:, 1], c=colors, s=2, cmap=colormap)  # Adjust `s` for marker size
# Remove axis labels and tick labels
plt.title("6K+200Custom UC_P2 Left Tissue PanCK")
plt.xlabel("")
plt.ylabel("")
plt.xticks([])  # Remove x-axis tick labels
plt.yticks([])  # Remove y-axis tick labels

# Remove gridlines
plt.grid(False)

# Add a colorbar to represent the continuous values
cbar = plt.colorbar(scatter, ax=plt.gca(), aspect=30, pad=0.02)
cbar.set_label(continuous_column, rotation=270, labelpad=15)


plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Subset data for specific slide
adata1_slide3_1k = adata_1k_1[adata_1k_1.obs['tissue'] == 'UC_P1_right']
coordinates = adata1_slide3_1k.obsm['spatial_fov']

category_column = 'only_1k_cell_cat_from_type'
categories = adata1_slide3_1k.obs[category_column].astype('category')

# Create a color palette
palette = sns.color_palette('tab20', len(categories.cat.categories))
colors = categories.cat.codes.map(dict(enumerate(palette)))

# Plotting
plt.figure(figsize=(8, 10))
scatter = plt.scatter(coordinates[:, 0], coordinates[:, 1], c=colors, s=2)  # Adjust `s` for marker size
plt.title("")

# Remove axis labels and tick labels
plt.xlabel("")
plt.ylabel("")
plt.xticks([])  # Remove x-axis tick labels
plt.yticks([])  # Remove y-axis tick labels

# Remove gridlines
plt.grid(False)

# Create a custom legend inside the plot at the top left
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=palette[i], markersize=10) 
           for i in range(len(categories.cat.categories))]
plt.legend(
    handles, 
    categories.cat.categories, 
    title="1K No Imp", 
    loc='upper left', 
    frameon=False,
    fontsize=12,           # Legend label font size
    title_fontsize=14      # Legend title font size
)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(False) 

# Add correlation annotation in bottom right
corr_text = (
    "Spearman's Correlation\n"
    "Epithelial cell & PanCK: 0.444 (p=0.0)\n"
    "Myeloid cell & CD68: 0.137 (p=4.3e-48)"
)

plt.text(
    0.98, 0.02,  # x, y in axes fraction
    corr_text,
    transform=plt.gca().transAxes,
    ha='right', va='bottom',
    fontsize=12,
    bbox=dict(facecolor='white', edgecolor='none', alpha=0.8, boxstyle='round,pad=0.3')
)

# Save to PDF
plt.savefig("1k_noimp_slide4_annotation.jpg", bbox_inches='tight', dpi=300)

plt.show()

# %%
[i for i in adata1_slide3_1k.obs['only_1k_cell_type_general'].unique().tolist() if i not in  adata1_slide3_1k.obs['v7_ywl_b_imp_cell_type_general'].unique().tolist()]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Define the custom palette with 32 distinct colors
custom_palette_35 = [
    "#1f77b4",  # 'B' - Dark Blue
    "#aec7e8",  # 'ADAMDEC1+ Fib' - Light Blue
    "#8fd1db",  # 'Activated Fib' - Light Blue
    "#8ac0ed",  # 'Crypt Top Fib' - Light Blue
    '#ace8e3', # Cycl fib
    "#a5daf2",  # 'Myofibroblast' - Light Blue
    "#9ad3d6",  # 'OGN+RSPO3+ Fib' - Light Blue
    "#80b7b5",  # 'Pericyte' - Light Blue
    '#c6d6f5', # SELENOP+ fib,
    "#ff7f0e",  # 'Endothelial' - Dark Orange
    "#ffbb78",  # 'Absoprtive Epi' - Light Orange
    '#f5d2b5', # Enteroendocrine
    "#f8c0a9",  # 'Inflamed Epi' - Light Orange
    "#f1a3a3",  # 'M cell' - Light Orange
    "#e39b5f",  # 'Secretive Epi' - Light Orange
    "#e07b5b",  # 'TA' - Light Orange
    "#df9f6e",  # 'Tuft' - Light Orange
    "#2ca02c",  # 'Granulocyte' - Dark Green
    "#98df8a",  # 'Cycl Myeloid' - Light Green 1
    "#8fa72b",  # 'DC' - Light Green 2
    "#9abf62",  # 'Mo-mac' - Light Green 3
    "#a1d99b",  # 'Neutrophil' - Light Green 4
    "#6b9f67",  # 'SELENOP+ Mac' - Light Green 5
    "#d65a69",  # 'NK' - Red
    "#ff9b99",  # 'Neuron' - Salmon
    "#9467bd",  # 'Plasma' - Dark Purple
    "#ebc2ed",  # 'CD4 Trm' - Lighter Purple 1
    "#c0a4de",  # 'CD8 Trm' - Lighter Purple 2
    "#e377c2",  # 'DN T' - Lighter Purple 3
    "#9b6fa3",  # 'Effector T' - Lighter Purple 4
    "#b175b6",  # 'Gd T' - Lighter Purple 5
    "#d2a2b8",  # 'MAIT' - Lighter Purple 6
    "#e4b5c9",  # 'Resting T' - Lighter Purple 7
    "#e1ace8",  # 'Tfh' - Lighter Purple 8
    "#b1b7d2",  # 'Treg' - Lighter Purple 9
]

# Assuming your data is in adata1_slide3_1k and you have the necessary columns
category_column = 'only_1k_cell_type_general'
category_from_type_column = 'only_1k_cell_cat_from_type'

# Sort the data by category and cell type
sorted_categories = adata1_slide3_1k.obs[[category_column, category_from_type_column]].drop_duplicates()
sorted_categories = sorted_categories.sort_values(by=[category_from_type_column, category_column])

# Create a mapping of the sorted categories to the custom color palette
category_to_color = {cat: custom_palette_35[i] for i, cat in enumerate(sorted_categories[category_column].unique())}

# Map the categories to the colors
categories = adata1_slide3_1k.obs[category_column].astype('category')
category_colors = categories.map(category_to_color)

# Plotting
plt.figure(figsize=(8.5, 10))
scatter = plt.scatter(adata1_slide3_1k.obsm['spatial_fov'][:, 0], 
                      adata1_slide3_1k.obsm['spatial_fov'][:, 1], 
                      c=category_colors, s=2)  # Adjust `s` for marker size
plt.title("1K UC_P1 Right Tissue Annotation")

# Remove axis labels and tick labels
plt.xlabel("")
plt.ylabel("")
plt.xticks([])  # Remove x-axis tick labels
plt.yticks([])  # Remove y-axis tick labels

# Remove gridlines
plt.grid(False)

# Create a custom legend outside the plot on the right
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10) 
           for color in custom_palette_35]
plt.legend(handles, sorted_categories[category_column].unique(), title="Cell Type", 
           loc='upper left', bbox_to_anchor=(1.05, 1), frameon=False)

plt.tight_layout()  # Ensure there’s no clipping of the legend
plt.show()

# %%
adata_1k_1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Subset data for specific slide
adata1_slide3_1k = adata_1k_1[adata_1k_1.obs['tissue'] == 'UC_P1_right']
coordinates = adata1_slide3_1k.obsm['spatial_fov']

category_column = 'v7_ywl_b_imp_cell_category_from_type_x' # no x
categories = adata1_slide3_1k.obs[category_column].astype('category')

# Create a color palette
palette = sns.color_palette('tab20', len(categories.cat.categories))
colors = categories.cat.codes.map(dict(enumerate(palette)))

# Plotting
plt.figure(figsize=(8, 10))
scatter = plt.scatter(coordinates[:, 0], coordinates[:, 1], c=colors, s=2)  # Adjust `s` for marker size
plt.title("")

# Remove axis labels and tick labels
plt.xlabel("")
plt.ylabel("")
plt.xticks([])  # Remove x-axis tick labels
plt.yticks([])  # Remove y-axis tick labels

# Remove gridlines
plt.grid(False)

# Create a custom legend inside the plot at the top left
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=palette[i], markersize=10) 
           for i in range(len(categories.cat.categories))]
plt.legend(
    handles, 
    categories.cat.categories, 
    title="1K GCN Imp", 
    loc='upper left', 
    frameon=False,
    fontsize=12,           # Legend label font size
    title_fontsize=14      # Legend title font size
)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(False) 

# Add correlation annotation in bottom right
corr_text = (
    "Spearman's Correlation\n"
    "Epithelial cell & PanCK: 0.499 (p=0.0)\n"
    "Myeloid cell & CD68: 0.229 (p=2.5e-133)"
)

plt.text(
    0.98, 0.02,  # x, y in axes fraction
    corr_text,
    transform=plt.gca().transAxes,
    ha='right', va='bottom',
    fontsize=12,
    bbox=dict(facecolor='white', edgecolor='none', alpha=0.8, boxstyle='round,pad=0.3')
)

# Save to PDF
plt.savefig("1k_ywl_imp_slide4_annotation.jpg", bbox_inches='tight', dpi=300)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Define the custom palette with 32 distinct colors
custom_palette_32 = [
    "#1f77b4",  # 'B' - Dark Blue
    "#aec7e8",  # 'ADAMDEC1+ Fib' - Light Blue
    "#8fd1db",  # 'Activated Fib' - Light Blue
    "#8ac0ed",  # 'Crypt Top Fib' - Light Blue
    "#a5daf2",  # 'Myofibroblast' - Light Blue
    "#9ad3d6",  # 'OGN+RSPO3+ Fib' - Light Blue
    "#80b7b5",  # 'Pericyte' - Light Blue
    "#ff7f0e",  # 'Endothelial' - Dark Orange
    "#ffbb78",  # 'Absoprtive Epi' - Light Orange
    "#f8c0a9",  # 'Inflamed Epi' - Light Orange
    "#f1a3a3",  # 'M cell' - Light Orange
    "#e39b5f",  # 'Secretive Epi' - Light Orange
    "#e07b5b",  # 'TA' - Light Orange
    "#df9f6e",  # 'Tuft' - Light Orange
    "#2ca02c",  # 'Granulocyte' - Dark Green
    "#98df8a",  # 'Cycl Myeloid' - Light Green 1
    "#8fa72b",  # 'DC' - Light Green 2
    "#9abf62",  # 'Mo-mac' - Light Green 3
    "#a1d99b",  # 'Neutrophil' - Light Green 4
    "#6b9f67",  # 'SELENOP+ Mac' - Light Green 5
    "#d65a69",  # 'NK' - Red
    "#ff9b99",  # 'Neuron' - Salmon
    "#9467bd",  # 'Plasma' - Dark Purple
    "#ebc2ed",  # 'CD4 Trm' - Lighter Purple 1
    "#c0a4de",  # 'CD8 Trm' - Lighter Purple 2
    "#e377c2",  # 'DN T' - Lighter Purple 3
    "#9b6fa3",  # 'Effector T' - Lighter Purple 4
    "#b175b6",  # 'Gd T' - Lighter Purple 5
    "#d2a2b8",  # 'MAIT' - Lighter Purple 6
    "#e4b5c9",  # 'Resting T' - Lighter Purple 7
    "#e1ace8",  # 'Tfh' - Lighter Purple 8
    "#b1b7d2",  # 'Treg' - Lighter Purple 9
]

# Assuming your data is in adata1_slide3_1k and you have the necessary columns
category_column = 'v7_ywl_b_imp_cell_type_general'
category_from_type_column = 'v7_ywl_b_imp_cell_category_from_type'

# Sort the data by category and cell type
sorted_categories = adata1_slide3_1k.obs[[category_column, category_from_type_column]].drop_duplicates()
sorted_categories = sorted_categories.sort_values(by=[category_from_type_column, category_column])

# Create a mapping of the sorted categories to the custom color palette
category_to_color = {cat: custom_palette_32[i] for i, cat in enumerate(sorted_categories[category_column].unique())}

# Map the categories to the colors
categories = adata1_slide3_1k.obs[category_column].astype('category')
category_colors = categories.map(category_to_color)

# Plotting
plt.figure(figsize=(8.5, 10))
scatter = plt.scatter(adata1_slide3_1k.obsm['spatial_fov'][:, 0], 
                      adata1_slide3_1k.obsm['spatial_fov'][:, 1], 
                      c=category_colors, s=2)  # Adjust `s` for marker size
plt.title("1K UC_P1 Right Tissue Imputation Annotation")

# Remove axis labels and tick labels
plt.xlabel("")
plt.ylabel("")
plt.xticks([])  # Remove x-axis tick labels
plt.yticks([])  # Remove y-axis tick labels

# Remove gridlines
plt.grid(False)

# Create a custom legend outside the plot on the right
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10) 
           for color in custom_palette_32]
plt.legend(handles, sorted_categories[category_column].unique(), title="Cell Type", 
           loc='upper left', bbox_to_anchor=(1.05, 1), frameon=False)

plt.tight_layout()  # Ensure there’s no clipping of the legend
plt.show()

# %%
adata_1k_1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Subset data for specific slide
adata1_slide3_1k = adata_1k_1[adata_1k_1.obs['tissue'] == 'UC_P1_right']
coordinates = adata1_slide3_1k.obsm['spatial_fov']

category_column = 'v7_tan_imp_cell_category_from_type'
categories = adata1_slide3_1k.obs[category_column].astype('category')

# Create a color palette
palette = sns.color_palette('tab20', len(categories.cat.categories))
colors = categories.cat.codes.map(dict(enumerate(palette)))

# Plotting
plt.figure(figsize=(8, 10))
scatter = plt.scatter(coordinates[:, 0], coordinates[:, 1], c=colors, s=2)  # Adjust `s` for marker size
plt.title("")

# Remove axis labels and tick labels
plt.xlabel("")
plt.ylabel("")
plt.xticks([])  # Remove x-axis tick labels
plt.yticks([])  # Remove y-axis tick labels

# Remove gridlines
plt.grid(False)

# Create a custom legend inside the plot at the top left
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=palette[i], markersize=10) 
           for i in range(len(categories.cat.categories))]
plt.legend(
    handles, 
    categories.cat.categories, 
    title="1K Tangram Imp", 
    loc='upper left', 
    frameon=False,
    fontsize=12,           # Legend label font size
    title_fontsize=14      # Legend title font size
)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(False) 

# Add correlation annotation in bottom right
corr_text = (
    "Spearman's Correlation\n"
    "Epithelial cell & PanCK: 0.364 (p=0.0)\n"
    "Myeloid cell & CD68: 0.222 (p=4.6e-133)"
)

plt.text(
    0.98, 0.02,  # x, y in axes fraction
    corr_text,
    transform=plt.gca().transAxes,
    ha='right', va='bottom',
    fontsize=12,
    bbox=dict(facecolor='white', edgecolor='none', alpha=0.8, boxstyle='round,pad=0.3')
)

# Save to PDF
plt.savefig("1k_tang_imp_slide4_annotation.jpg", bbox_inches='tight', dpi=300)

plt.show()

# %%
coordinates = adata1_slide3_1k.obsm['spatial_fov']

continuous_column = 'Max.PanCK'
continuous_values = adata1_slide3_1k.obs[continuous_column]

# Choose a colormap (e.g., 'viridis', 'plasma', 'coolwarm')
colormap = plt.cm.viridis

# Normalize the continuous values to range between 0 and 1 for the colormap
norm = plt.Normalize(vmin=continuous_values.min(), vmax=continuous_values.max())
colors = colormap(norm(continuous_values))

# Plotting
plt.figure(figsize=(9, 10))
scatter = plt.scatter(coordinates[:, 0], coordinates[:, 1], c=colors, s=2, cmap=colormap)  # Adjust `s` for marker size
# Remove axis labels and tick labels
plt.title("1K UC_P2 Left Tissue PanCK")
plt.xlabel("")
plt.ylabel("")
plt.xticks([])  # Remove x-axis tick labels
plt.yticks([])  # Remove y-axis tick labels

# Remove gridlines
plt.grid(False)

# Add a colorbar to represent the continuous values
cbar = plt.colorbar(scatter, ax=plt.gca(), aspect=30, pad=0.02)
cbar.set_label(continuous_column, rotation=270, labelpad=15)


plt.show()

# %%
coordinates = adata1_slide3_1k.obsm['spatial_fov']

continuous_column = 'Max.CD68'
continuous_values = adata1_slide3_1k.obs[continuous_column]

# Choose a colormap (e.g., 'viridis', 'plasma', 'coolwarm')
colormap = plt.cm.viridis

# Normalize the continuous values to range between 0 and 1 for the colormap
norm = plt.Normalize(vmin=continuous_values.min(), vmax=continuous_values.max())
colors = colormap(norm(continuous_values))

# Plotting
plt.figure(figsize=(9, 10))
scatter = plt.scatter(coordinates[:, 0], coordinates[:, 1], c=colors, s=2, cmap=colormap)  # Adjust `s` for marker size
# Remove axis labels and tick labels
plt.title("1K UC_P2 Left Tissue CD68")
plt.xlabel("")
plt.ylabel("")
plt.xticks([])  # Remove x-axis tick labels
plt.yticks([])  # Remove y-axis tick labels

# Remove gridlines
plt.grid(False)

# Add a colorbar to represent the continuous values
cbar = plt.colorbar(scatter, ax=plt.gca(), aspect=30, pad=0.02)
cbar.set_label(continuous_column, rotation=270, labelpad=15)


plt.show()

# %% [markdown]
# # fov level

# %%
from matplotlib.colors import ListedColormap
categories = adata_1k_1.obs['v7_ywl_b_imp_cell_category_from_type'].astype('category')
color_mapping = {cat: palette[i] for i, cat in enumerate(categories.cat.categories)}
colors = categories.cat.codes.map(dict(enumerate(palette)))
cmap = ListedColormap([color_mapping[cat] for cat in categories.cat.categories])
cmap

# %%
import matplotlib.pyplot as plt
import squidpy as sq
import seaborn as sns
import pandas as pd

adata_1k_1.obs['v7_ywl_b_imp_cell_type_general'] = (
    adata_1k_1.obs['v7_ywl_b_imp_cell_type_general']
    .replace('SELENOP+ Fib', 'Senescent Fib')
)

# Define the custom palette with 35 distinct colors and corresponding cell types
cell_types_order = [
    'B', 'ADAMDEC1+ Fib', 'Activated Fib', 'Crypt Top Fib', 'Cycl Fib', 
    'Myofibroblast', 'OGN+RSPO3+ Fib', 'Pericyte', 'Senescent Fib',
    'Endothelial', 'Absoprtive Epi', 'Enteroendocrine', 'Inflamed Epi', 
    'M cell', 'Secretive Epi', 'TA', 'Tuft', 
    'Granulocyte', 'Cycl Myeloid', 'DC', 'Mo-mac', 'Neutrophil', 
    'SELENOP+ Mac', 'NK', 'Neuron', 
    'Plasma', 'CD4 Trm', 'CD8 Trm', 'DN T', 'Effector T', 
    'Gd T', 'MAIT', 'Resting T', 'Tfh', 'Treg'
]

custom_palette_35 = [
    "#1f77b4", "#aec7e8", "#8fd1db", "#8ac0ed", '#ace8e3', "#a5daf2", "#9ad3d6", "#80b7b5", '#c6d6f5',
    "#ff7f0e", "#ffbb78", '#f5d2b5', "#f8c0a9", "#f1a3a3", "#e39b5f", "#e07b5b", "#df9f6e",
    "#2ca02c", "#98df8a", "#8fa72b", "#9abf62", "#a1d99b", "#6b9f67", "#d65a69", "#ff9b99",
    "#9467bd", "#ebc2ed", "#c0a4de", "#e377c2", "#9b6fa3", "#b175b6", "#d2a2b8", "#e4b5c9",
    "#e1ace8", "#b1b7d2"
]

# Filter for cell types present in the current FOV
category_column = 'v7_ywl_b_imp_cell_type_general'
category_from_type_column = 'v7_ywl_b_imp_cell_category_from_type'

# Filter only the cells present in the selected FOV
adata_fov = adata_1k_1[adata_1k_1.obs["fov"].isin(["44"])].copy()

# Drop categories not present in the ordered list
adata_fov = adata_fov[adata_fov.obs[category_column].isin(cell_types_order)]

# Sort the dataframe by the cell type order
adata_fov.obs[category_column] = pd.Categorical(
    adata_fov.obs[category_column], 
    categories=cell_types_order, 
    ordered=True
)

# Remove NaN values for the category_column
adata_fov = adata_fov[adata_fov.obs[category_column].notna()]

# Sort by category_column within the obs DataFrame, then reorder adata_fov
adata_fov = adata_fov[adata_fov.obs.sort_values(by=category_column).index]

# Create a mapping of the available categories to the custom color palette
available_categories = adata_fov.obs[category_column].unique()
category_to_color = {cat: custom_palette_35[cell_types_order.index(cat)] for cat in available_categories}

# Store the color mapping in adata_fov.uns for squidpy to recognize
adata_fov.uns[f"{category_column}_colors"] = [category_to_color[cat] for cat in available_categories]

# Plot with squidpy using the assigned colors
sq.pl.spatial_segment(
    adata_fov,
    color=category_column,
    library_key="fov",
    library_id=["44"],
    seg_cell_id="cell_ID",
    seg_outline=True, ncols=3
)

# %%
import matplotlib.pyplot as plt
import squidpy as sq
import seaborn as sns
import pandas as pd

# Define the custom palette with 35 distinct colors and corresponding cell types
cell_types_order = [
    'B', 'ADAMDEC1+ Fib', 'Activated Fib', 'Crypt Top Fib', 'Cycl Fib', 
    'Myofibroblast', 'OGN+RSPO3+ Fib', 'Pericyte', 'SELENOP+ Fib',
    'Endothelial', 'Absoprtive Epi', 'Enteroendocrine', 'Inflamed Epi', 
    'M cell', 'Secretive Epi', 'TA', 'Tuft', 
    'Granulocyte', 'Cycl Myeloid', 'DC', 'Mo-mac', 'Neutrophil', 
    'SELENOP+ Mac', 'NK', 'Neuron', 
    'Plasma', 'CD4 Trm', 'CD8 Trm', 'DN T', 'Effector T', 
    'Gd T', 'MAIT', 'Resting T', 'Tfh', 'Treg'
]

custom_palette_35 = [
    "#1f77b4", "#aec7e8", "#8fd1db", "#8ac0ed", '#ace8e3', "#a5daf2", "#9ad3d6", "#80b7b5", '#c6d6f5',
    "#ff7f0e", "#ffbb78", '#f5d2b5', "#f8c0a9", "#f1a3a3", "#e39b5f", "#e07b5b", "#df9f6e",
    "#2ca02c", "#98df8a", "#8fa72b", "#9abf62", "#a1d99b", "#6b9f67", "#d65a69", "#ff9b99",
    "#9467bd", "#ebc2ed", "#c0a4de", "#e377c2", "#9b6fa3", "#b175b6", "#d2a2b8", "#e4b5c9",
    "#e1ace8", "#b1b7d2"
]

# Filter for cell types present in the current FOV
category_column = 'v7_ywl_b_imp_cell_type_general'
category_from_type_column = 'v7_ywl_b_imp_cell_category_from_type'

# Filter only the cells present in the selected FOV
adata_fov = adata_1k_1[adata_1k_1.obs["fov"].isin(["44"])].copy()

# Drop categories not present in the ordered list
adata_fov = adata_fov[adata_fov.obs[category_column].isin(cell_types_order)]

# Sort the dataframe by the cell type order
adata_fov.obs[category_column] = pd.Categorical(
    adata_fov.obs[category_column], 
    categories=cell_types_order, 
    ordered=True
)

# Remove NaN values for the category_column
adata_fov = adata_fov[adata_fov.obs[category_column].notna()]

# Sort by category_column within the obs DataFrame, then reorder adata_fov
adata_fov = adata_fov[adata_fov.obs.sort_values(by=category_column).index]

# Create a mapping of the available categories to the custom color palette
available_categories = adata_fov.obs[category_column].unique()
category_to_color = {cat: custom_palette_35[cell_types_order.index(cat)] for cat in available_categories}

# Store the color mapping in adata_fov.uns for squidpy to recognize
adata_fov.uns[f"{category_column}_colors"] = [category_to_color[cat] for cat in available_categories]

# Plot with squidpy using the assigned colors and remove the legend
sq.pl.spatial_segment(
    adata_fov,
    color=category_column,
    library_key="fov",
    library_id=["44"],
    seg_cell_id="cell_ID",
    seg_outline=True,
    legend_loc=None  # Removes the legend
)

# %%
cmap = plt.cm.Reds
sq.pl.spatial_segment(
    adata_1k_1,
    color="Max.PanCK",
    library_key="fov",
    library_id=["44"],
    seg_cell_id="cell_ID",
    seg_outline=True,
    cmap=cmap  # Dynamically ordered colormap
)

# %%
cmap = plt.cm.Reds
sq.pl.spatial_segment(
    adata_1k_1,
    color="Max.CD68",
    library_key="fov",
    library_id=["44"],
    seg_cell_id="cell_ID",
    seg_outline=True,
    cmap=cmap  # Dynamically ordered colormap
)

# %% [markdown]
# # SPEARMAN PROTEIN + ANNO

# %% [markdown]
# ## cd68

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide3_wtx.obs['myeloid_binary_aucell_cell_cat'] = [1 if i =='Myeloid' else 0 for i in adata1_slide3_wtx.obs['aucell_cell_category_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide3_wtx.obs['Max.CD68'], adata1_slide3_wtx.obs['myeloid_binary_aucell_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide3_6k_custom.obs['myeloid_binary_aucell_cell_cat'] = [1 if i =='Myeloid' else 0 for i in adata1_slide3_6k_custom.obs['aucell_cell_category_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide3_6k_custom.obs['Max.CD68'], adata1_slide3_6k_custom.obs['myeloid_binary_aucell_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide3_6k.obs['myeloid_binary_aucell_cell_cat'] = [1 if i =='Myeloid' else 0 for i in adata1_slide3_6k.obs['aucell_cell_category_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide3_6k.obs['Max.CD68'], adata1_slide3_6k.obs['myeloid_binary_aucell_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide3_1k.obs['myeloid_binary_v7_ywl_b_imp_cell_cat'] = [1 if i == 'Myeloid' else 0 for i in adata1_slide3_1k.obs['v7_ywl_b_imp_cell_category_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide3_1k.obs['Max.CD68'], adata1_slide3_1k.obs['myeloid_binary_v7_ywl_b_imp_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide3_1k.obs['myeloid_binary_v7_tan_imp_cell_cat'] = [1 if i == 'Myeloid' else 0 for i in adata1_slide3_1k.obs['v7_tan_imp_cell_category_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide3_1k.obs['Max.CD68'], adata1_slide3_1k.obs['myeloid_binary_v7_tan_imp_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide3_1k.obs['myeloid_binary_v7_stp_imp_cell_cat'] = [1 if i == 'Myeloid' else 0 for i in adata1_slide3_1k.obs['v7_stp_imp_cell_category_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide3_1k.obs['Max.CD68'], adata1_slide3_1k.obs['myeloid_binary_v7_stp_imp_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide3_1k.obs['myeloid_binary_only_1k_cell_cat'] = [1 if i == 'Myeloid' else 0 for i in adata1_slide3_1k.obs['only_1k_cell_cat_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide3_1k.obs['Max.CD68'], adata1_slide3_1k.obs['myeloid_binary_only_1k_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %% [markdown]
# ## panck

# %%
adata1_slide3_wtx.obs['panck_binary_3000'] = [1 if i >=3000 else 0 for i in adata1_slide3_wtx.obs['Max.PanCK'].tolist() ]
adata1_slide3_wtx.obs['panck_binary_4000'] = [1 if i >=4000 else 0 for i in adata1_slide3_wtx.obs['Max.PanCK'].tolist() ]
adata1_slide3_wtx.obs['panck_binary_5000'] = [1 if i >=5000 else 0 for i in adata1_slide3_wtx.obs['Max.PanCK'].tolist() ]
adata1_slide3_wtx.obs['panck_binary_6000'] = [1 if i >=6000 else 0 for i in adata1_slide3_wtx.obs['Max.PanCK'].tolist() ]

# %%
adata1_slide3_wtx.obs['panck_binary_3000'].value_counts()

# %%
adata1_slide3_wtx.obs['panck_binary_4000'].value_counts()

# %%
adata1_slide3_wtx.obs['panck_binary_5000'].value_counts()

# %%
adata1_slide3_wtx.obs['panck_binary_6000'].value_counts()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Subset data for specific slide
coordinates = adata1_slide3_wtx.obsm['spatial_fov']

category_column = 'panck_binary_3000'
categories = adata1_slide3_wtx.obs[category_column].astype('category')

# Create a color palette
palette = sns.color_palette('tab10', len(categories.cat.categories))
colors = categories.cat.codes.map(dict(enumerate(palette)))

# Plotting
plt.figure(figsize=(8, 10))
scatter = plt.scatter(coordinates[:, 0], coordinates[:, 1], c=colors, s=2)  # Adjust `s` for marker size
plt.title("WTX UC_P1 PanCK Binary 3000")

# Remove axis labels and tick labels
plt.xlabel("")
plt.ylabel("")
plt.xticks([])  # Remove x-axis tick labels
plt.yticks([])  # Remove y-axis tick labels

# Remove gridlines
plt.grid(False)

# Create a custom legend inside the plot at the top right
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=palette[i], markersize=10) 
           for i in range(len(categories.cat.categories))]
plt.legend(handles, categories.cat.categories, title="Major Cell Type", loc='upper left', frameon=False)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Subset data for specific slide
coordinates = adata1_slide3_wtx.obsm['spatial_fov']

category_column = 'panck_binary_4000'
categories = adata1_slide3_wtx.obs[category_column].astype('category')

# Create a color palette
palette = sns.color_palette('tab10', len(categories.cat.categories))
colors = categories.cat.codes.map(dict(enumerate(palette)))

# Plotting
plt.figure(figsize=(8, 10))
scatter = plt.scatter(coordinates[:, 0], coordinates[:, 1], c=colors, s=2)  # Adjust `s` for marker size
plt.title("WTX UC_P1 PanCK Binary 4000")

# Remove axis labels and tick labels
plt.xlabel("")
plt.ylabel("")
plt.xticks([])  # Remove x-axis tick labels
plt.yticks([])  # Remove y-axis tick labels

# Remove gridlines
plt.grid(False)

# Create a custom legend inside the plot at the top right
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=palette[i], markersize=10) 
           for i in range(len(categories.cat.categories))]
plt.legend(handles, categories.cat.categories, title="Major Cell Type", loc='upper left', frameon=False)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Subset data for specific slide
coordinates = adata1_slide3_wtx.obsm['spatial_fov']

category_column = 'panck_binary_5000'
categories = adata1_slide3_wtx.obs[category_column].astype('category')

# Create a color palette
palette = sns.color_palette('tab10', len(categories.cat.categories))
colors = categories.cat.codes.map(dict(enumerate(palette)))

# Plotting
plt.figure(figsize=(8, 10))
scatter = plt.scatter(coordinates[:, 0], coordinates[:, 1], c=colors, s=2)  # Adjust `s` for marker size
plt.title("WTX UC_P1 PanCK Binary 5000")

# Remove axis labels and tick labels
plt.xlabel("")
plt.ylabel("")
plt.xticks([])  # Remove x-axis tick labels
plt.yticks([])  # Remove y-axis tick labels

# Remove gridlines
plt.grid(False)

# Create a custom legend inside the plot at the top right
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=palette[i], markersize=10) 
           for i in range(len(categories.cat.categories))]
plt.legend(handles, categories.cat.categories, title="Major Cell Type", loc='upper left', frameon=False)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Subset data for specific slide
coordinates = adata1_slide3_wtx.obsm['spatial_fov']

category_column = 'panck_binary_6000'
categories = adata1_slide3_wtx.obs[category_column].astype('category')

# Create a color palette
palette = sns.color_palette('tab10', len(categories.cat.categories))
colors = categories.cat.codes.map(dict(enumerate(palette)))

# Plotting
plt.figure(figsize=(8, 10))
scatter = plt.scatter(coordinates[:, 0], coordinates[:, 1], c=colors, s=2)  # Adjust `s` for marker size
plt.title("WTX UC_P1 PanCK Binary 6000")

# Remove axis labels and tick labels
plt.xlabel("")
plt.ylabel("")
plt.xticks([])  # Remove x-axis tick labels
plt.yticks([])  # Remove y-axis tick labels

# Remove gridlines
plt.grid(False)

# Create a custom legend inside the plot at the top right
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=palette[i], markersize=10) 
           for i in range(len(categories.cat.categories))]
plt.legend(handles, categories.cat.categories, title="Major Cell Type", loc='upper left', frameon=False)

plt.show()

# %% [markdown]
# Decided to use binary epithelial/myeloid anno and continuous panck and cd68 value. Using Yiming’s approach of hard thresholding on the protein markers don’t show clear distinction e.g., 3000 vs 6000 panck threshold – hard to decide which is right

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide3_wtx.obs['epi_binary_aucell_cell_cat'] = [1 if i =='Epithelial' else 0 for i in adata1_slide3_wtx.obs['aucell_cell_category_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide3_wtx.obs['Max.PanCK'], adata1_slide3_wtx.obs['epi_binary_aucell_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide3_6k.obs['epi_binary_aucell_cell_cat'] = [1 if i =='Epithelial' else 0 for i in adata1_slide3_6k.obs['aucell_cell_category_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide3_6k.obs['Max.PanCK'], adata1_slide3_6k.obs['epi_binary_aucell_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide3_6k_custom.obs['epi_binary_aucell_cell_cat'] = [1 if i =='Epithelial' else 0 for i in adata1_slide3_6k_custom.obs['aucell_cell_category_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide3_6k_custom.obs['Max.PanCK'], adata1_slide3_6k_custom.obs['epi_binary_aucell_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide3_1k.obs['epi_binary_v7_ywl_b_imp_cell_cat'] = [1 if i == 'Epithelial' else 0 for i in adata1_slide3_1k.obs['v7_ywl_b_imp_cell_category_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide3_1k.obs['Max.PanCK'], adata1_slide3_1k.obs['epi_binary_v7_ywl_b_imp_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide3_1k.obs['epi_binary_v7_tan_imp_cell_cat'] = [1 if i == 'Epithelial' else 0 for i in adata1_slide3_1k.obs['v7_tan_imp_cell_category_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide3_1k.obs['Max.PanCK'], adata1_slide3_1k.obs['epi_binary_v7_tan_imp_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide3_1k.obs['epi_binary_v7_stp_imp_cell_cat'] = [1 if i == 'Epithelial' else 0 for i in adata1_slide3_1k.obs['v7_stp_imp_cell_category_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide3_1k.obs['Max.PanCK'], adata1_slide3_1k.obs['epi_binary_v7_stp_imp_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide3_1k.obs['epi_binary_only_1k_cell_cat'] = [1 if i == 'Epithelial' else 0 for i in adata1_slide3_1k.obs['only_1k_cell_cat_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide3_1k.obs['Max.PanCK'], adata1_slide3_1k.obs['epi_binary_only_1k_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %% [markdown]
# # SPEARMAN PROTEIN + ANNO bad looking tissue piece

# %% [markdown]
# ## cd68 1k

# %%
adata1_slide1_1k = adata_1k_1[adata_1k_1.obs['tissue'] == 'UC_P2_left']

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide1_1k.obs['myeloid_binary_v7_ywl_b_imp_cell_cat'] = [1 if i == 'Myeloid' else 0 for i in adata1_slide1_1k.obs['v7_ywl_b_imp_cell_category_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide1_1k.obs['Max.CD68'], adata1_slide1_1k.obs['myeloid_binary_v7_ywl_b_imp_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide1_1k.obs['myeloid_binary_v7_tan_imp_cell_cat'] = [1 if i == 'Myeloid' else 0 for i in adata1_slide1_1k.obs['v7_tan_imp_cell_category_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide1_1k.obs['Max.CD68'], adata1_slide1_1k.obs['myeloid_binary_v7_tan_imp_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide1_1k.obs['myeloid_binary_only_1k_cell_cat'] = [1 if i == 'Myeloid' else 0 for i in adata1_slide1_1k.obs['only_1k_cell_cat_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide1_1k.obs['Max.CD68'], adata1_slide1_1k.obs['myeloid_binary_only_1k_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %% [markdown]
# ## panck 1k

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide1_1k.obs['epi_binary_v7_ywl_b_imp_cell_cat'] = [1 if i == 'Epithelial' else 0 for i in adata1_slide1_1k.obs['v7_ywl_b_imp_cell_category_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide1_1k.obs['Max.PanCK'], adata1_slide1_1k.obs['epi_binary_v7_ywl_b_imp_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide1_1k.obs['epi_binary_v7_tan_imp_cell_cat'] = [1 if i == 'Epithelial' else 0 for i in adata1_slide1_1k.obs['v7_tan_imp_cell_category_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide1_1k.obs['Max.PanCK'], adata1_slide1_1k.obs['epi_binary_v7_tan_imp_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %%
import scipy.stats as stats

# Create a binary column for 'Myeloid' presence
adata1_slide1_1k.obs['epi_binary_only_1k_cell_cat'] = [1 if i == 'Epithelial' else 0 for i in adata1_slide1_1k.obs['only_1k_cell_cat_from_type'].tolist() ]

# Calculate Spearman's correlation between Max.CD68 and 'Myeloid' presence
spearman_corr, p_value = stats.spearmanr(adata1_slide1_1k.obs['Max.PanCK'], adata1_slide1_1k.obs['epi_binary_only_1k_cell_cat'])

print(f'Spearman correlation: {spearman_corr}, p-value: {p_value}')

# %% [markdown]
# # otsu based binary

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.filters import threshold_otsu

# Step 1: Extract CD68 expression
cd68_vals = adata1_slide3_1k.obs['Max.CD68'].values
cd68_vals = cd68_vals[~np.isnan(cd68_vals)]  # remove NaNs if any

# Step 2: Apply Otsu’s method
otsu_thresh = threshold_otsu(cd68_vals)

# Step 3: Plot histogram
plt.figure(figsize=(8, 5))
plt.hist(cd68_vals, bins=100, color='steelblue', alpha=0.8)
plt.axvline(otsu_thresh, color='red', linestyle='--', label=f"Otsu Threshold = {otsu_thresh:.2f}")
plt.xlabel('CD68 Expression')
plt.ylabel('Number of Cells')
plt.title('Histogram of CD68 Expression with Otsu Threshold')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.filters import threshold_otsu

# Step 1: Extract CD68 expression
panck_vals = adata1_slide3_1k.obs['Max.PanCK'].values
panck_vals = panck_vals[~np.isnan(panck_vals)]  # remove NaNs if any

# Step 2: Apply Otsu’s method
otsu_thresh = threshold_otsu(panck_vals)

# Step 3: Plot histogram
plt.figure(figsize=(8, 5))
plt.hist(panck_vals, bins=100, color='steelblue', alpha=0.8)
plt.axvline(otsu_thresh, color='red', linestyle='--', label=f"Otsu Threshold = {otsu_thresh:.2f}")
plt.xlabel('PanCK Expression')
plt.ylabel('Number of Cells')
plt.title('Histogram of PanCK Expression with Otsu Threshold')
plt.legend()
plt.tight_layout()
plt.show()

# %%
adata1_slide3_1k.obs[(adata1_slide3_1k.obs['Max.CD68']>=24524) & (adata1_slide3_1k.obs['Max.PanCK']>=10460)]

# %%
binary_ct = []
for i,j in adata1_slide3_1k.obs.iterrows():
    if j['Max.CD68']>=24524 and j['Max.PanCK']<10460:
        binary_ct.append('CD68+')
    elif j['Max.CD68']<24524 and j['Max.PanCK']>=10460:
        binary_ct.append('PanCK+')
    else:
        binary_ct.append('Others')

# %%
adata1_slide3_1k.obs['binary_prt_ct']=binary_ct

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Subset data for specific slide
coordinates = adata1_slide3_1k.obsm['spatial_fov']

# Define the category column and convert to categorical
category_column = 'binary_prt_ct'
categories = adata1_slide3_1k.obs[category_column].astype('category')

# Define custom colors
custom_palette = {
    'Others': 'lightgray',
    'PanCK+': 'orange',
    'CD68+': 'green'
}

# Map colors to categories
colors = categories.map(custom_palette)

# Plotting
plt.figure(figsize=(8, 10))
scatter = plt.scatter(coordinates[:, 0], coordinates[:, 1], c=colors, s=2)
plt.title("")

# Remove axis labels and tick labels
plt.xlabel("")
plt.ylabel("")
plt.xticks([])
plt.yticks([])

# Remove gridlines
plt.grid(False)

# Create a custom legend
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=custom_palette[label], markersize=10)
           for label in custom_palette]
plt.legend(handles, custom_palette.keys(), title="Protein (Otsu Threshold)", loc='upper left', frameon=False,   
    fontsize=12,           # Legend label font size
    title_fontsize=14  )

ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(False) 

# Save to PDF
plt.savefig("1k_protein_slide4_annotation.jpg", bbox_inches='tight', dpi=300)

plt.show()

# %%
adata

# %% [markdown]
# # co-occurrence analysis

# %%
adata_wtx.obs['slide']

# %%
adata1_slide3 = adata_wtx[adata_wtx.obs['slide'] == 'UC_batch1_slide3']
adata1_slide3

# %%
adata1_slide3_1k = adata_1k[adata_1k.obs['tissue'] == 'UC_P1_left']
adata1_slide3_1k

# %%
adata1_slide4 = adata_wtx[adata_wtx.obs['slide'] == 'UC_batch1_slide4']
adata1_slide4

# %%
adata1_slide4_1k = adata_1k[adata_1k.obs['tissue'] == 'UC_P1_right']
adata1_slide4_1k

# %%
adata1_slide4.obs['aucell_cell_type_short'].unique().tolist()

# %%
fib_mye_other_cell_cat = []
for i,j in zip(adata1_slide4.obs['aucell_cell_category_from_type'].tolist(),adata1_slide4.obs['aucell_cell_type_short'].tolist()):
    if j == 'Mac S+XS-' or j == 'Mac S+SG+':
        fib_mye_other_cell_cat.append('Mac S+')
    elif i == 'Myeloid' and 'DC' not in j:
        fib_mye_other_cell_cat.append(j)

    elif i == 'Myeloid' and 'DC' in j:
        fib_mye_other_cell_cat.append('DC')
    elif 'Activ Fib' in j:
        fib_mye_other_cell_cat.append('Activ Fibroblast')
    elif  'Crypt Top' in j:
        fib_mye_other_cell_cat.append('Crypt Top Fibroblast')
    elif  'Myofib' in j:
        fib_mye_other_cell_cat.append('Myofibroblast')
    elif  'Peri' in j:
        fib_mye_other_cell_cat.append('Pericyte')
    elif  'T-interact Fib' in j:
        fib_mye_other_cell_cat.append(j)
    elif j in ['ADAMDEC1+ Fib','OGN+RSPO3+ Fib','SELENOP+ Fib','Cycl Fib']:
        fib_mye_other_cell_cat.append('Other Fibroblast')
    elif i == 'NK' or i== 'T':
        fib_mye_other_cell_cat.append('T/NK')
    else:
        fib_mye_other_cell_cat.append(i)
adata1_slide4.obs['fib_mye_other_cell_cat']=fib_mye_other_cell_cat
adata1_slide4.obs['fib_mye_other_cell_cat'] = adata1_slide4.obs['fib_mye_other_cell_cat'].astype('category')

# %%
adata1_slide4.obs['fib_mye_other_cell_cat'].value_counts()

# %%
fib_mye_other_cell_cat = []
for i,j in zip(adata1_slide3.obs['aucell_cell_category_from_type'].tolist(),adata1_slide3.obs['aucell_cell_type_short'].tolist()):
    if j == 'Mac S+XS-' or j == 'Mac S+SG+':
        fib_mye_other_cell_cat.append('Mac S+')
    elif i == 'Myeloid' and 'DC' not in j:
        fib_mye_other_cell_cat.append(j)

    elif i == 'Myeloid' and 'DC' in j:
        fib_mye_other_cell_cat.append('DC')
    elif 'Activ Fib' in j:
        fib_mye_other_cell_cat.append('Activ Fibroblast')
    elif  'Crypt Top' in j:
        fib_mye_other_cell_cat.append('Crypt Top Fibroblast')
    elif  'Myofib' in j:
        fib_mye_other_cell_cat.append('Myofibroblast')
    elif  'Peri' in j:
        fib_mye_other_cell_cat.append('Pericyte')
    elif  'T-interact Fib' in j:
        fib_mye_other_cell_cat.append(j)
    elif j in ['ADAMDEC1+ Fib','OGN+RSPO3+ Fib','SELENOP+ Fib','Cycl Fib']:
        fib_mye_other_cell_cat.append('Other Fibroblast')
    elif i == 'NK' or i== 'T':
        fib_mye_other_cell_cat.append('T/NK')
    else:
        fib_mye_other_cell_cat.append(i)
adata1_slide3.obs['fib_mye_other_cell_cat']=fib_mye_other_cell_cat
adata1_slide3.obs['fib_mye_other_cell_cat'] = adata1_slide3.obs['fib_mye_other_cell_cat'].astype('category')

# %%
adata1_slide3.obs['fib_mye_other_cell_cat'].value_counts()

# %%
fib_mye_other_cell_cat = []
for i,j in zip(adata1_slide4_1k.obs['v7_ywl_b_imp_cell_category_from_type'].tolist(),adata1_slide4_1k.obs['v7_ywl_b_imp_cell_type_short'].tolist()):
    if j == 'Mac S+XS-' or j == 'Mac S+SG+':
        fib_mye_other_cell_cat.append('Mac S+')
    elif i == 'Myeloid' and 'DC' not in j:
        fib_mye_other_cell_cat.append(j)
    elif 'Activ Fib' in j:
        fib_mye_other_cell_cat.append('Activ Fibroblast')
    elif  'Crypt Top' in j:
        fib_mye_other_cell_cat.append('Crypt Top Fibroblast')
    elif  'Myofib' in j:
        fib_mye_other_cell_cat.append('Myofibroblast')
    elif  'Peri' in j:
        fib_mye_other_cell_cat.append('Pericyte')
    elif  'T-interact Fib' in j:
        fib_mye_other_cell_cat.append(j)
    elif j in ['ADAMDEC1+ Fib','OGN+RSPO3+ Fib','SELENOP+ Fib','Cycl Fib']:
        fib_mye_other_cell_cat.append('Other Fibroblast')
    elif i == 'NK' or i== 'T':
        fib_mye_other_cell_cat.append('T/NK')
    else:
        fib_mye_other_cell_cat.append(i)
adata1_slide4_1k.obs['fib_mye_other_cell_cat']=fib_mye_other_cell_cat
adata1_slide4_1k.obs['fib_mye_other_cell_cat'] = adata1_slide4_1k.obs['fib_mye_other_cell_cat'].astype('category')

# %%
adata1_slide4_1k.obs['fib_mye_other_cell_cat'].value_counts()

# %%
fib_mye_other_cell_cat = []
for i,j in zip(adata1_slide3_1k.obs['v7_ywl_b_imp_cell_category_from_type'].tolist(),adata1_slide3_1k.obs['v7_ywl_b_imp_cell_type_short'].tolist()):
    if j == 'Mac S+XS-' or j == 'Mac S+SG+':
        fib_mye_other_cell_cat.append('Mac S+')
    elif i == 'Myeloid' and 'DC' not in j:
        fib_mye_other_cell_cat.append(j)
    elif 'Activ Fib' in j:
        fib_mye_other_cell_cat.append('Activ Fibroblast')
    elif  'Crypt Top' in j:
        fib_mye_other_cell_cat.append('Crypt Top Fibroblast')
    elif  'Myofib' in j:
        fib_mye_other_cell_cat.append('Myofibroblast')
    elif  'Peri' in j:
        fib_mye_other_cell_cat.append('Pericyte')
    elif  'T-interact Fib' in j:
        fib_mye_other_cell_cat.append(j)
    elif j in ['ADAMDEC1+ Fib','OGN+RSPO3+ Fib','SELENOP+ Fib','Cycl Fib']:
        fib_mye_other_cell_cat.append('Other Fibroblast')
    elif i == 'NK' or i== 'T':
        fib_mye_other_cell_cat.append('T/NK')
    else:
        fib_mye_other_cell_cat.append(i)
adata1_slide3_1k.obs['fib_mye_other_cell_cat']=fib_mye_other_cell_cat
adata1_slide3_1k.obs['fib_mye_other_cell_cat'] = adata1_slide3_1k.obs['fib_mye_other_cell_cat'].astype('category')

# %%
adata1_slide3_1k.obs['fib_mye_other_cell_cat'].value_counts()

# %%
# https://squidpy.readthedocs.io/en/stable/notebooks/examples/graph/compute_co_occurrence.html
sq.gr.co_occurrence(
    adata1_slide4_1k,
    cluster_key="fib_mye_other_cell_cat",
)

# %%
# https://squidpy.readthedocs.io/en/stable/notebooks/examples/graph/compute_co_occurrence.html
sq.gr.co_occurrence(
    adata1_slide3_1k,
    cluster_key="fib_mye_other_cell_cat",
)

# %%
# https://squidpy.readthedocs.io/en/stable/notebooks/examples/graph/compute_co_occurrence.html
sq.gr.co_occurrence(
    adata1_slide4,
    cluster_key="fib_mye_other_cell_cat",
)

# %%
# https://squidpy.readthedocs.io/en/stable/notebooks/examples/graph/compute_co_occurrence.html
sq.gr.co_occurrence(
    adata1_slide3,
    cluster_key="fib_mye_other_cell_cat",
)

# %%
from matplotlib.colors import ListedColormap
custom_palette = [
    "#FF9999", "#66B3FF", "#99FF99", "#FFCC99", "#FFD700", 
    "#FF69B4", "#8A2BE2", "#00BFFF", "#ADFF2F", "#FF4500", 
    "#FF6347", "#4682B4", "#DDA0DD", "#20B2AA", "#778899", 
    "#FFA07A", "#FFE4B5", "#7B68EE", "#D2691E", "#00FA9A", 
    "#B22222", "#32CD32", "#FFA500"
]
colormap = ListedColormap(custom_palette)

# %%
# Create the co-occurrence plot
sq.pl.co_occurrence(
    adata1_slide4_1k,
    cluster_key="fib_mye_other_cell_cat",
    clusters="Activ Fibroblast",
    palette=colormap
)

# Set x-axis limits (cutting off at 2000)
plt.xlim(60, 300)  # Adjust according to your data range

# Show the plot
plt.show()

# %%
# Create the co-occurrence plot
sq.pl.co_occurrence(
    adata1_slide3_1k,
    cluster_key="fib_mye_other_cell_cat",
    clusters="Activ Fibroblast",
    palette=colormap
)

# Set x-axis limits (cutting off at 2000)
plt.xlim(60, 300)  # Adjust according to your data range

# Show the plot
plt.show()

# %%
# Create the co-occurrence plot
sq.pl.co_occurrence(
    adata1_slide4,
    cluster_key="fib_mye_other_cell_cat",
    clusters="Activ Fibroblast",
    palette=colormap
)

# Set x-axis limits (cutting off at 2000)
plt.xlim(60, 300)  # Adjust according to your data range

# Show the plot
plt.show()

# %%
# Create the co-occurrence plot
sq.pl.co_occurrence(
    adata1_slide3,
    cluster_key="fib_mye_other_cell_cat",
    clusters="Activ Fibroblast",
    palette=colormap
)

# Set x-axis limits (cutting off at 2000)
plt.xlim(60, 300)  # Adjust according to your data range

# Show the plot
plt.show()
